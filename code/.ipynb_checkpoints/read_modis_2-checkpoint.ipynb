# %%
import os
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
# from pyhdf.SD import SD, SDC

# %%
from pyhdf.SD import SD, SDC

# %%
PATH = "../data/modis_dataset/"
# FILE_NAME = PATH + "MOD13Q1.A2008161.h08v05.006.2015176070634.hdf"
FILE_NAME = PATH + "AIRS.2002.08.01.L3.RetStd_H031.v4.0.21.0.G06104133732.hdf"
hdf = SD(FILE_NAME, SDC.READ)

# %%
# List available SDS datasets.
print(hdf.datasets())
# Out:
# {'TotO3_D_sdev': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 58), 'Temperature_MW_D': (('TempPrsLvls:descending_MW_only', 'YDim:descending_MW_only', 'XDim:descending_MW_only'), (24, 180, 360), 5, 118), 'SurfSkinTemp_D_ct': (('YDim:descending', 'XDim:descending'), (180, 360), 22, 63), 'TotH2OVap_A_ct': (('YDim:ascending', 'XDim:ascending'), (180, 360), 22, 5), 'GPHeight_MW_A_ct': (('TempPrsLvls:ascending_MW_only', 'YDim:ascending_MW_only', 'XDim:ascending_MW_only'), (24, 180, 360), 22, 103), 'OLR_D': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 68), 'TotH2OVap_MW_D_ct': (('YDim:descending_MW_only', 'XDim:descending_MW_only'), (180, 360), 22, 110), 'Temperature_MW_D_sdev': (('TempPrsLvls:descending_MW_only', 'YDim:descending_MW_only', 'XDim:descending_MW_only'), (24, 180, 360), 5, 120), 'SurfAirTemp_D_sdev': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 61), 'TotH2OVap_MW_A_sdev': (('YDim:ascending_MW_only', 'XDim:ascending_MW_only'), (180, 360), 5, 98), 'GPHeight_MW_D_ct': (('TempPrsLvls:descending_MW_only', 'YDim:descending_MW_only', 'XDim:descending_MW_only'), (24, 180, 360), 22, 116), 'Longitude': (('YDim:location', 'XDim:location'), (180, 360), 5, 122), 'Temperature_A_sdev': (('TempPrsLvls:ascending', 'YDim:ascending', 'XDim:ascending'), (24, 180, 360), 5, 45), 'EmisIR_D': (('EmisLvls:descending', 'YDim:descending', 'XDim:descending'), (4, 180, 360), 5, 74), 'RelHumid_D_sdev': (('H2OPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (12, 180, 360), 5, 88), 'SurfPres_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 18), 'EmisIR_A_ct': (('EmisLvls:ascending', 'YDim:ascending', 'XDim:ascending'), (4, 180, 360), 22, 26), 'EmisIR_D_sdev': (('EmisLvls:descending', 'YDim:descending', 'XDim:descending'), (4, 180, 360), 5, 76), 'OLR_A': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 19), 'SurfAirTemp_A': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 10), 'TotO3_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 9), 'Temperature_MW_D_ct': (('TempPrsLvls:descending_MW_only', 'YDim:descending_MW_only', 'XDim:descending_MW_only'), (24, 180, 360), 22, 119), 'GPHeight_D_ct': (('TempPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (24, 180, 360), 22, 78), 'TotH2OVap_D_sdev': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 55), 'Latitude': (('YDim:location', 'XDim:location'), (180, 360), 5, 121), 'CloudFrc_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 33), 'TotH2OVap_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 6), 'Temperature_D_ct': (('TempPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (24, 180, 360), 22, 93), 'TotH2OVap_MW_A': (('YDim:ascending_MW_only', 'XDim:ascending_MW_only'), (180, 360), 5, 96), 'EmisIR_A': (('EmisLvls:ascending', 'YDim:ascending', 'XDim:ascending'), (4, 180, 360), 5, 25), 'SurfSkinTemp_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 15), 'CloudFrcVis_A_ct': (('YDim:ascending', 'XDim:ascending'), (180, 360), 22, 47), 'TotalCounts_D': (('YDim:descending', 'XDim:descending'), (180, 360), 22, 49), 'OLR_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 21), 'CloudTopPres_D_sdev': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 85), 'RelHumid_D': (('H2OPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (12, 180, 360), 5, 86), 'OLR_A_ct': (('YDim:ascending', 'XDim:ascending'), (180, 360), 22, 20), 'TotO3_D': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 56), 'Temperature_D_sdev': (('TempPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (24, 180, 360), 5, 94), 'ClrOLR_A_ct': (('YDim:ascending', 'XDim:ascending'), (180, 360), 22, 23), 'H2OVapMMR_D_ct': (('H2OPrsLvls:descending', 'YDim:descending', 'XDim:descending'), (12, 180, 360), 22, 90), 'CloudTopPres_A_sdev': (('YDim:ascending', 'XDim:ascending'), (180, 360), 5, 36), 'SurfPres_D': (('YDim:descending', 'XDim:descending'), (180, 360), 5, 65), 'EmisMW_MW_A_ct': ...

# %%
# Read dataset.
DATAFIELD_NAME='RelHumid_A'
data3D = hdf.select(DATAFIELD_NAME)
data = data3D[11,:,:]

# Read geolocation dataset.
lat = hdf.select('Latitude')
latitude = lat[:,:]
lon = hdf.select('Longitude')
longitude = lon[:,:]

# %%
print(latitude)
# Out:
# [[ 89.5  89.5  89.5 ...,  89.5  89.5  89.5]
#  [ 88.5  88.5  88.5 ...,  88.5  88.5  88.5]
#  [ 87.5  87.5  87.5 ...,  87.5  87.5  87.5]
#  ...,
#  [-87.5 -87.5 -87.5 ..., -87.5 -87.5 -87.5]
#  [-88.5 -88.5 -88.5 ..., -88.5 -88.5 -88.5]
#  [-89.5 -89.5 -89.5 ..., -89.5 -89.5 -89.5]]

# %%
m = Basemap(projection='cyl', resolution='l', llcrnrlat=-90, urcrnrlat = 90, llcrnrlon=-180, urcrnrlon = 180)
m.drawcoastlines(linewidth=0.5)
m.drawparallels(np.arange(-90., 120., 30.), labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180., 181., 45.), labels=[0, 0, 0, 1])
x, y = m(longitude, latitude)
m.pcolormesh(x, y, data)
# Out:
# /Users/visethsean/anaconda/lib/python3.4/site-packages/mpl_toolkits/basemap/__init__.py:3488: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   x = ma.masked_values(np.where(x > 1.e20,1.e20,x), 1.e20)
# /Users/visethsean/anaconda/lib/python3.4/site-packages/mpl_toolkits/basemap/__init__.py:3497: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   plt.sci(ret)

# %%
FILE_NAME = PATH + "MOD13Q1.A2008161.h08v05.006.2015176070634.hdf"
hdf = SD(FILE_NAME, SDC.READ)
# List available SDS datasets.
print(hdf.datasets())
# Out:
# {'250m 16 days composite day of the year': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 10), '250m 16 days relative azimuth angle': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 9), '250m 16 days VI Quality': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 23, 2), '250m 16 days view zenith angle': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 7), '250m 16 days EVI': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 1), '250m 16 days pixel reliability': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 20, 11), '250m 16 days sun zenith angle': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 8), '250m 16 days NDVI': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 0), '250m 16 days blue reflectance': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 5), '250m 16 days red reflectance': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 3), '250m 16 days NIR reflectance': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 4), '250m 16 days MIR reflectance': (('YDim:MODIS_Grid_16DAY_250m_500m_VI', 'XDim:MODIS_Grid_16DAY_250m_500m_VI'), (4800, 4800), 22, 6)}

# %%
# Read dataset.
DATAFIELD_NAME='250m 16 days NDVI'
data = hdf.select(DATAFIELD_NAME)

# %%
data.attributes()
# Out:
# {'_FillValue': -3000,
#  'add_offset': 0.0,
#  'add_offset_err': 0.0,
#  'calibrated_nt': 5,
#  'long_name': '250m 16 days NDVI',
#  'scale_factor': 10000.0,
#  'scale_factor_err': 0.0,
#  'units': 'NDVI',
#  'valid_range': [-2000, 10000]}

# %%
data.dimensions()
# Out:
# {'XDim:MODIS_Grid_16DAY_250m_500m_VI': 4800,
#  'YDim:MODIS_Grid_16DAY_250m_500m_VI': 4800}

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-b814148a9517> in <module>()
# ----> 1 data['XDim']
#
# /Users/visethsean/anaconda/lib/python3.4/site-packages/pyhdf/SD.py in __getitem__(self, elem)
#    1810
#    1811         # Compute arguments to 'SDreaddata_0()'.
# -> 1812         start, count, stride = self.__buildStartCountStride(elem)
#    1813         # Get elements.
#    1814         return self.get(start, count, stride)
#
# /Users/visethsean/anaconda/lib/python3.4/site-packages/pyhdf/SD.py in __buildStartCountStride(self, elem)
#    2089             # Bug
#    2090             else:
# -> 2091                 raise ValueError("Bug: unexpected element type to __getitem__")
#    2092
#    2093             # Clip end index (except if unlimited dimension)
#
# ValueError: Bug: unexpected element type to __getitem__

# %%
# Out:
# (-2000, 10000)

# %%
m = Basemap(projection='cyl', resolution='l', llcrnrlat=-90, urcrnrlat = 90, llcrnrlon=-180, urcrnrlon = 180)
m.drawcoastlines(linewidth=0.5)
m.drawparallels(np.arange(-90., 120., 30.), labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180., 181., 45.), labels=[0, 0, 0, 1])
x, y = m(longitude, latitude)
data = data3D[1,:,:]
m.pcolormesh(x, y, data)
# Out:
# /Users/visethsean/anaconda/lib/python3.4/site-packages/mpl_toolkits/basemap/__init__.py:3488: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   x = ma.masked_values(np.where(x > 1.e20,1.e20,x), 1.e20)
# /Users/visethsean/anaconda/lib/python3.4/site-packages/mpl_toolkits/basemap/__init__.py:3497: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   plt.sci(ret)
